# %%
import pandas as pd
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
data = {
    'daily': [11, 25, 39, 44, 58, 67, 81, 99],
    'sunday': [12, 24, 35, 48, 59, 67, 78, 84],
}
df = pd.DataFrame(data)
print(df.columns)
model = smf.ols("sunday ~ daily", data=df).fit()
sns.regplot(x="daily", y="sunday", data=df)
plt.title("Regression Plot of Sunday vs Daily")
plt.show()
# Out:
# Index(['daily', 'sunday'], dtype='object')

# %%
(model.rsquared, model.rsquared_adj)
# Out:
# (0.9709930636056381, 0.9661585742065778)

# %%
newdata=pd.Series([200,200])
data_pred=pd.DataFrame(newdata,columns=['daily'])
model.predict(data_pred)
# Out:
# 0    179.011731
# 1    179.011731
# dtype: float64

# %%
df.shape
# Out:
# (8, 2)

# %%
df.corr
# Out:
# <bound method DataFrame.corr of    daily  sunday
# 0     11      12
# 1     25      24
# 2     39      35
# 3     44      48
# 4     58      59
# 5     67      67
# 6     81      78
# 7     99      84>

# %%
df_new = df[['daily','sunday']]
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   daily   8 non-null      int64
#  1   sunday  8 non-null      int64
# dtypes: int64(2)
# memory usage: 260.0 bytes

# %%
df_new.corr()
# Out:
#           daily   sunday
# daily   1.00000  0.98539
# sunday  0.98539  1.00000

# %%
import seaborn as sns
sns.distplot(df['daily'])
import seaborn as sns
sns.distplot(df['sunday'])
# Out:
# <ipython-input-33-cd429660278b>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['daily'])
# <ipython-input-33-cd429660278b>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sunday'])
# <Axes: xlabel='sunday', ylabel='Density'>

# %%
model.params
# Out:
# Intercept    4.676043
# daily        0.871678
# dtype: float64

# %%
(model.rsquared, model.rsquared_adj)
# Out:
# (0.9709930636056381, 0.9661585742065778)
